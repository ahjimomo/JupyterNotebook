# %% [markdown]
# ## Project Introduction
#
# Our target is to source for a static website to pull out information around the role of a Business Analyst in Australia from https://www.monster.com/jobs/search/
#
# The script would pull out the results from the website & return all the specific job postings for the user to vet through easily and access for job application.
#
# ##### Platform
#
# We are using Python 3.7.3 on Jupyter Notebook to implement this script
#
# ##### Information
# This script is prepared by Nicky Ng (@ahjimomo) as of 13 May 2020

# %% [markdown]
# ---

# %% [markdown]
# ### Preparation: Packages & HTML Pull

# %%
import requests
import pprint
from bs4 import BeautifulSoup

# Designate URL & pull the HTML
URL = "https://www.monster.com/jobs/search/?q=Business-Analyst&where=Australia"
page = requests.get(URL)


# Analyse URL
pprint.pprint(URL)
pprint.pprint(page)
# Out:
# 'https://www.monster.com/jobs/search/?q=Business-Analyst&where=Australia'
# <Response [200]>

# %%
# Creating the BeautifulSoup object that contains the scraped content

soup = BeautifulSoup(page.content, "html.parser")

# %%
# Finding all the results we want on Business Analyst

results = soup.find(id = "ResultsContainer")

print(results.prettify())
# Out:
# <div class="mux-custom-scroll" data-extend="left" data-mux="customScroll" data-target="html" id="ResultsContainer">
#  <div class="scrollable" id="ResultsScrollable">
#   <div class="mux-apas-ads" data-ads='[{"sizes":[1,1],"placementId":14162549,"id":"bad1"},{"sizes":[1,1],"placementId":14343737,"id":"bad2"},{"sizes":[728,90],"placementId":14343738,"id":"bad3"}]' data-config='{"targeting":{"Site":"United States","mURL":"https%3a%2f%2fwww.monster.com%2fjobs%2fsearch%2f%3fq%3dBusiness-Analyst%26where%3dAustralia","Page":"Job Search Results","mesco":[1300087001001,4300715001001]},"member":3525}' data-mux="apasAds">
#   </div>
#   <div class="mux-search-results" data-content-target="#JobPreview" data-emulated-click-attr="coretrackclickauto" data-is-dynamic="true" data-jhash-size="10" data-jhash-url="https://www.monster.com/jobs/search/jhpagination?q=Business-Analyst&amp;where=Australia" data-jv-non-job-content="-1" data-mux="searchResults" data-results-max="250" data-results-page="1" data-results-per-page="25" data-results-placeholder="job-item-placeholder-template" data-results-target="#SearchResults" data-results-template="job-item-template" data-results-total="250" data-results-url="https://www.monster.com/jobs/search/pagination/?q=Business-Analyst&amp;where=Australia&amp;isDynamicPage=true&amp;isMKPagination=true" data-total-search-results="11624">
#    <div class="mux-card mux-job-card" id="SearchResults">
#     <section class="card-content">
#      <div class="flex-row">
#       <div class="summary">
#        <p>
#         Showing Business Analyst jobs
#        </p>
#       </div>
#       <i aria-hidden="true" class="icon icon-magnify">
#       </i>
#      </div>
#     </section>
#     <section class="card-content" data-jobid="217762269" data-postingid="cfc820a7-4721-4673-8920-41b9f7b15018" onclick="MKImpressionTrackingMouseDownHijack(this, event)">
#      <div class="flex-row">
#       <div class="mux-company-logo thumbnail">
#       </div>
#       <div class="summary">
#        <header class="card-header">
#         <h2 class="title">
#          <a data-bypass="true" data-m_impr_a_placement_id="Permanent Page JSR2CW" data-m_impr_j_cid="3561" data-m_impr_j_coc="xcolsolifx" data-m_impr_j_jawsid="431932984" data-m_impr_j_jobid="217762269" data-m_impr_j_jpm="1" data-m_impr_j_jpt="1" data-m_impr_j_lat="39.7512" data-m_impr_j_lid="363" data-m_impr_j_long="-104.9975" data-m_impr_j_occid="11734" data-m_impr_j_p="1" data-m_impr_j_postingid="cfc820a7-4721-4673-8920-41b9f7b15018" data-m_impr_j_pvc="monster" data-m_impr_s_t="t" data-m_impr_uuid
data-m_impr_j_pvc="monster" data-m_impr_s_t="t" data-m_impr_uuid="6e783748-caf6-40bc-8249-d79daafee096" href="https://job-openings.monster.com/business-analyst-long-beach-ca-us-tristar-insurance-group/214866260" onclick="clickJobTitle('plid=882&amp;pcid=3561&amp;poccid=11734','Business Analyst',''); clickJobTitleSiteCat('{&quot;events.event48&quot;:&quot;true&quot;,&quot;eVar25&quot;:&quot;Business Analyst&quot;,&quot;eVar66&quot;:&quot;Monster&quot;,&quot;eVar67&quot;:&quot;Permanent Page JSR2CW&quot;,&quot;eVar26&quot;:&quot;xw35170770wx_Tristar Insurance Group&quot;,&quot;eVar31&quot;:&quot;Long Beach_CA_&quot;,&quot;prop22&quot;:&quot;Employee&quot;,&quot;prop24&quot;:&quot;2020-04-27T12:00&quot;,&quot;eVar53&quot;:&quot;1300087001001&quot;,&quot;eVar50&quot;:&quot;Duration&quot;,&quot;eVar74&quot;:&quot;regular&quot;}')">
#           Business Analyst
#          </a>
#         </h2>
#        </header>
#        <div class="company">
#         <span class="name">
#          Tristar Insurance Group
#         </span>
#         <ul class="list-inline">
#         </ul>
#        </div>
#        <div class="location">
#         <span class="name">
#          Long Beach, CA
#         </span>
#        </div>
#       </div>
#       <div class="meta flex-col">
#        <time datetime="2017-05-26T12:00">
#         15 days ago
#        </time>
#        <span class="mux-tooltip applied-only" data-mux="tooltip" title="Applied">
#         <i aria-hidden="true" class="icon icon-applied">
#         </i>
#         <span class="sr-only">
#          Applied
#         </span>
#        </span>
#        <span class="mux-tooltip saved-only" data-mux="tooltip" title="Saved">
#         <i aria-hidden="true" class="icon icon-saved">
#         </i>
#         <span class="sr-only">
#          Saved
#         </span>
#        </span>
#       </div>
#      </div>
#     </section>
#     <section class="card-content" data-jobid="215421618" data-postingid="43e37332-2be7-4b14-9959-0933e824905f" onclick="MKImpressionTrackingMouseDownHijack(this, event)">
#      <div class="flex-row">
#       <div class="mux-company-logo thumbnail is-loaded">
#        <img alt="Sivaltech Inc." src="https://coda.newjobs.com/api/imagesproxy/ms/clu/xw26/xw265630363wx/branding/58sivaltech-inc/Sivaltech-Inc-logo.png"/>
#       </div>
#       <div class="summary">
#        <header class="card-header">
#         <h2 class="title">
#          <a data-bypass="true" data-m_impr_a_placement_id="Permanent Page JSR2CW" data-m_impr_j_cid="3561" data-m_impr_j_coc="xw265630363wx" data-m_impr_j_jawsid="419743741" data-m_impr_j_jobid="215421618" data-m_impr_j_jpm="1" data-m_impr_j_jpt="1" data-m_impr_j_lat="32.8952" data-m_impr_j_lid="354" data-m_impr_j_long="-117.2051" data-m_impr_j_occid="11734" data-m_impr_j_p="25" data-m_impr_j_postingid="43e37332-2be7-4b14-9959-0933e824905f" data-m_impr_j_pvc="monster" data-m_impr_s_t="t" data-m_impr_uuid="b4f3e862-2a84-4449-9726-fdecbd21d4c0" href="https://job-openings.monster.com/business-analyst-san-diego-ca-us-sivaltech-inc/215421618" onclick="clickJobTitle('plid=354&amp;pcid=3561&amp;poccid=11734','Business Analyst',''); clickJobTitleSiteCat('{&quot;events.event48&quot;:&quot;true&quot;,&quot;eVar25&quot;:&quot;Business Analyst&quot;,&quot;eVar66&quot;:&quot;Monster&quot;,&quot;eVar67&quot;:&quot;Permanent Page JSR2CW&quot;,&quot;eVar26&quot;:&quot;xw265630363wx_Sivaltech Inc.&quot;,&quot;eVar31&quot;:&quot;San Diego_CA_&quot;,&quot;prop22&quot;:&quot;Employee&quot;,&quot;prop24&quot;:&quot;2020-04-27T12:00&quot;,&quot;eVar53&quot;:&quot;1300087001001&quot;,&quot;eVar50&quot;:&quot;Duration&quot;,&quot;eVar74&quot;:&quot;logo&quot;}')">
#           Business Analyst
#          </a>
#         </h2>
#        </header>
#        <div class="company">
#         <span class="name">
#          Sivaltech Inc.
#         </span>
#         <ul class="list-inline">
#         </ul>
#        </div>
#        <div class="location">
#         <span class="name">
#          San Diego, CA
#         </span>
#        </div>
#       </div>
#       <div class="meta flex-col">
#        <time datetime="2017-05-26T12:00">
#         15 days ago
#        </time>
#        <span class="mux-tooltip applied-only" data-mux="tooltip" title="Applied">
#         <i aria-hidden="true" class="icon icon-applied">
#         </i>
#         <span class="sr-only">
#          Applied
#         </span>
#        </span>
#        <span class="mux-tooltip saved-only" data-mux="tooltip" title="Saved">
#         <i aria-hidden="true" class="icon icon-saved">
#         </i>
#         <span class="sr-only">
#          Saved
#         </span>
#        </span>
#       </div>
#      </div>
#     </section>
#    </div>
#    <a class="mux-btn btn-secondary load-more-btn" data-action="fetch" href="" id="loadMoreJobs" role="button">
#     Load more jobs
#    </a>
#    <a class="mux-btn btn-secondary no-more-jobs-btn disabled" id="noMoreResults" role="button" style="display:none">
#     No More Results
#    </a>
#   </div>
#  </div>
# </div>

# %% [markdown]
# ---

# %% [markdown]
# ### Searching: Finding jobs available based on keywords in post title

# %%
## We can see that each job posting is wrapped by a section of 'card-content' class
# We can use soup to pull these posting and print them out

job_elems = results.find_all("section", class_ = "card-content")

## Printing everything found
## REMOVED TO SAVE SPACE, UNCOMMENT TO RUN SCRIPT ##
#for job_elem in job_elems:
#    print(job_elem, end = "\n" * 2)

# %%
# Printing only the key details we need
# To remove the whitespace & and only return the details we want, we will use .strip() & .text on the results
# In our case, we might also encounter NoneType object that could return error, we will ignore it for now
for job_elem in job_elems:
    title_elem = job_elem.find("h2", class_ = "title")
    company_elem = job_elem.find("div", class_ = "company")
    location_elem = job_elem.find("div", class_ = "location")
    
    if None in (title_elem, company_elem, location_elem):
        continue
    
    print(title_elem.text.strip())
    print(company_elem.text.strip())
    print(location_elem.text.strip())
    print()
# Out:
# Salesforce Business Analyst
# Avco consulting Inc
# Denver, CO
#
# Business Analyst- Child Welfare
# CSG Government Solutions
#
#
# Business Analyst
# Project Consulting Group
# MINNEAPOLIS, MN
#
# Business Analyst
# Clinton Savings Bank
# Clinton, MA
#
# Business analyst with Lifesciences domain Exp
# Cliecon Solutions Inc
# Foster city, CA
#
# Senior Business Analyst
# Eze Castle Software LLC
# Boston, MA
#
# Service Delivery Business Analyst
# Ericsson Inc.
# Plano, TX
#
# Pharma Regulatory Business Analyst
# Cygnus Professionals Inc.
# Branchburg, NJ
#
# Business Analyst w/ UAT Test lead
# ASAP
# Charlotte, NC
#
# Jr. Business Analyst
# CBTS a Cincinnati Bell Company
# Cincinnati, OH
#
# Business Analyst - SQL
# CyberCoders
# Willow Grove, PA
#
# Business Analyst, JD Edwards - Downers Grove, IL
# Silgan Containers LLC
# DOWNERS GROVE, IL
#
# D365 Business Analyst
# Applied Resource Group
# Atlanta, GA
#
# Salesforce Business Analyst with Healthcare Experience
# Wilco Source, LLC
# Scottsdale, AZ
#
# Business Analyst (BPMN - Business Process Modeling Notation)
# LingaTech, Inc.
# Harrisburg, PA
#
# Business Analyst (Maximo / Oracle PL/SQL scripts)
# Trigyn Technologies Inc
# Manhattan, NY
#
# EDI Business Analyst / QA Tester
# Axiom Systems, Inc
# Frederick, MD
#
# Junior Business Analyst
# SNI Technology
# Castle Rock, CO
#
# Business Analyst - Security Masterdata
# Spectra Group Inc.
# jersey City, NJ
#
# Business Analyst
# Veracity Consulting
# Topeka, KS
#
# Technical Business Analyst - 1993
# The MIL Corporation (MIL)
# Washington D.C.
#
# Business Analyst/Design - L3
# V2Soft
# Auburn Hills, MI
#
# ERP Business Analyst
# Ford Meter Box Company
# Wabash, IN
#
# Business Analyst
# Tristar Insurance Group
# Long Beach, CA
#
# Business Analyst
# Sivaltech Inc.
# San Diego, CA

# %%
# Making it dynamic, we can allow a keyword search based on specification

keyword = "salesforce"

# Let's say we want to go specific to find results that looks for applicants with experience in Salesforce

jobs_keyword = results.find_all("h2", string = lambda text: keyword in text.lower())

if len(jobs_keyword) > 0:
    print("Yes you have", len(jobs_keyword), "matches!\n")
    
    for job_elem in job_elems:
        title_elem = job_elem.find("h2", string = lambda text: keyword in text.lower())
        company_elem = job_elem.find("div", class_ = "company")
        location_elem = job_elem.find("div", class_ = "location")
    
        if None in (title_elem, company_elem, location_elem):
            continue
        
        print(title_elem.text.strip())
        print(company_elem.text.strip())
        print(location_elem.text.strip())
        print()
else:
    print("There is 0 matches. Please try other keywords.")
# Out:
# Yes you have 2 matches!
#
# Salesforce Business Analyst
# Avco consulting Inc
# Denver, CO
#
# Salesforce Business Analyst with Healthcare Experience
# Wilco Source, LLC
# Scottsdale, AZ

# %%
# To find only specific keyword roles among Business Analyst role + the URL to job application
# We can find where the URL are in the HTML script and implement accordingly

jobs_keyword = results.find_all("h2", string = lambda text: keyword in text.lower())

for job_keyword in jobs_keyword:
    link = job_keyword.find('a')['href']
    
    print(job_keyword.text.strip())
    print(f"Apply here: {link}\n")
# Out:
# Salesforce Business Analyst
# Apply here: https://job-openings.monster.com/salesforce-business-analyst-denver-co-us-avco-consulting-inc/217762269
#
# Salesforce Business Analyst with Healthcare Experience
# Apply here: https://job-openings.monster.com/salesforce-business-analyst-with-healthcare-experience-scottsdale-az-us-wilco-source-llc/217668736
